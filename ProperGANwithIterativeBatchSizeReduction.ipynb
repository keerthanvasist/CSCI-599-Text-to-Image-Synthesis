# %%
# Import required libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import math

import os
import random
import sklearn
from scipy.ndimage import imread
# import skipthoughts
import nltk

# %matplotlib inline
# Load cifar-10 data


def load_images(path):
    working_dir = path
    file_list = []
    for root, dirs, files in os.walk(working_dir):
        for filename in files:
            if filename.endswith('.jpg'):
                file_list.append(root + "/" + filename) 
    images = []
    for myfile in file_list:
        image = imread(myfile)
        images.append(image)
    num_images = len(images)
    images=np.asarray(images)
    
    images=images.reshape(num_images,1,28,28)
    images=images.reshape(images.shape[0], 1, 28, 28).transpose(
        0, 2, 3, 1).astype("uint8")
       
    return images / 255.0
    
def load_input_sentences():
    sentences = np.load('sentences.npy')
    solutions = np.load('solutions.npy')
    
    return sentences, solutions

def load_data(intput_path, output_path):
    input_images = load_images(intput_path)
    input_sentences, labels = load_input_sentences()
    output_images = load_images(output_path)
    
    inputs = list(zip(input_images, input_sentences, labels, output_images))
    random.shuffle(inputs)
    input_images, input_sentences, labels,output_images = zip(*inputs)
    
    return input_images, input_sentences, labels, output_images


train_input_path = './dataset/input/'
train_output_path = './dataset/output/'
train_images, train_sentences, train_labels, train_output= load_data(train_input_path, train_output_path)
for i in range(8):
    nums = ''
    for j in range(8):
        nums = nums + str(train_labels[i*8+j]) + ' '
    print (nums)
# Out:
# 25
# 25 6
# 25 6 25
# 25 6 25 8
# 25 6 25 8 1
# 25 6 25 8 1 16
# 25 6 25 8 1 16 12
# 25 6 25 8 1 16 12 4
# 36
# 36 36
# 36 36 40
# 36 36 40 48
# 36 36 40 48 0
# 36 36 40 48 0 64
# 36 36 40 48 0 64 81
# 36 36 40 48 0 64 81 25
# 36
# 36 16
# 36 16 21
# 36 16 21 45
# 36 16 21 45 16
# 36 16 21 45 16 81
# 36 16 21 45 16 81 48
# 36 16 21 45 16 81 48 0
# 18
# 18 9
# 18 9 25
# 18 9 25 0
# 18 9 25 0 1
# 18 9 25 0 1 9
# 18 9 25 0 1 9 40
# 18 9 25 0 1 9 40 25
# 36
# 36 1
# 36 1 9
# 36 1 9 7
# 36 1 9 7 45
# 36 1 9 7 45 25
# 36 1 9 7 45 25 0
# 36 1 9 7 45 25 0 30
# 25
# 25 48
# 25 48 0
# 25 48 0 16
# 25 48 0 16 0
# 25 48 0 16 0 9
# 25 48 0 16 0 9 12
# 25 48 0 16 0 9 12 4
# 9
# 9 4
# 9 4 81
# 9 4 81 0
# 9 4 81 0 9
# 9 4 81 0 9 64
# 9 4 81 0 9 64 81
# 9 4 81 0 9 64 81 36
# 9
# 9 24
# 9 24 64
# 9 24 64 36
# 9 24 64 36 10
# 9 24 64 36 10 1
# 9 24 64 36 10 1 81
# 9 24 64 36 10 1 81 35

# %%
def viz_grid(Xs, padding):
    N, H, W, C = Xs.shape
    grid_size = int(math.ceil(math.sqrt(N)))
    grid_height = H * grid_size + padding * (grid_size + 1)
    grid_width = W * grid_size + padding * (grid_size + 1)
    grid = np.zeros((grid_height, grid_width, C))
    next_idx = 0
    y0, y1 = padding, H + padding
    for y in range(grid_size):
        x0, x1 = padding, W + padding
        for x in range(grid_size):
            if next_idx < N:
                img = Xs[next_idx]
                grid[y0:y1, x0:x1] = img
                next_idx += 1
            x0 += W + padding
            x1 += W + padding
        y0 += H + padding
        y1 += H + padding
    return grid

def max_pool(input, kernel_size, stride):
    ksize = [1, kernel_size, kernel_size, 1]
    strides = [1, stride, stride, 1]
    return tf.nn.max_pool(input, ksize=ksize, strides=strides, padding='SAME')

def conv2d(input, kernel_size, stride, num_filter, name = 'conv2d'):
    with tf.variable_scope(name):
        stride_shape = [1, stride, stride, 1]
        filter_shape = [kernel_size, kernel_size, input.get_shape()[3], num_filter]

        W = tf.get_variable('w', filter_shape, tf.float32, tf.random_normal_initializer(0.0, 0.02))
        b = tf.get_variable('b', [1, 1, 1, num_filter], initializer = tf.constant_initializer(0.0))
        return tf.nn.conv2d(input, W, stride_shape, padding = 'SAME') + b

def conv2d_transpose(input, kernel_size, stride, num_filter, name = 'conv2d_transpose'):
    with tf.variable_scope(name):
        stride_shape = [1, stride, stride, 1]
        filter_shape = [kernel_size, kernel_size, num_filter, input.get_shape()[3]]
        output_shape = tf.stack([tf.shape(input)[0], tf.shape(input)[1] * 2, tf.shape(input)[2] * 2, num_filter])

        W = tf.get_variable('w', filter_shape, tf.float32, tf.random_normal_initializer(0.0, 0.02))
        b = tf.get_variable('b', [1, 1, 1, num_filter], initializer = tf.constant_initializer(0.0))
        return tf.nn.conv2d_transpose(input, W, output_shape, stride_shape, padding = 'SAME') + b

def fc(input, num_output, name = 'fc'):
    with tf.variable_scope(name):
        num_input = input.get_shape()[1]
        W = tf.get_variable('w', [num_input, num_output], tf.float32, tf.random_normal_initializer(0.0, 0.02))
        b = tf.get_variable('b', [num_output], initializer = tf.constant_initializer(0.0))
        return tf.matmul(input, W) + b

def batch_norm(input, is_training):
    out = tf.contrib.layers.batch_norm(input, decay = 0.99, center = True, scale = True,
                                       is_training = is_training, updates_collections = None)
    return out

def leaky_relu(input, alpha = 0.2):
    return tf.maximum(alpha * input, input)


class DCGAN(object):

    def __init__(self):
        self.num_epoch = 16
        self.batch_size = 64
        self.log_step = 50
        self.visualize_step = 200
        self.code_size = 256
        self.learning_rate = 1e-4
        self.vis_learning_rate = 1e-2
        self.recon_steps = 100
        self.actmax_steps = 100
        
        self._dis_called = False
        self._gen_called = False

        self.tracked_noise = np.random.normal(0, 1, [64, self.code_size])
        self.arr = tf.placeholder(tf.int32, [10,self.batch_size])

        self.real_sentences = tf.placeholder(tf.float32, [None, 4800])
        self.real_images = tf.placeholder(tf.float32, [None, 28,28,1])
        self.real_output_images = tf.placeholder(tf.float32, [None, 28,28,1])
        
        self.real_labels = tf.placeholder(tf.float32, [None, 1])
        self.fake_labels = tf.placeholder(tf.float32, [None, 1])
        
        #self.fake_label = tf.placeholder(tf.float32, [None, 100])
        self.noise = tf.placeholder(tf.float32, [None, 256])
        
        self.is_train = tf.placeholder(tf.bool)
        
        with tf.variable_scope('actmax'):
            self.actmax_code = tf.get_variable('actmax_code', [1, self.code_size],
                                               initializer = tf.constant_initializer(0.0))
        
        self._init_ops()

    def _discriminator(self, input, text_embedding, image_input):
        # We have multiple instances of the discriminator in the same computation graph,
        # so set variable sharing if this is not the first invocation of this function.
        with tf.variable_scope('dis', reuse = self._dis_called):
            self._dis_called = True
            
            dis_fc1 = fc(text_embedding, 784, 'fc1')
            dis_relu1 = leaky_relu(dis_fc1)
            dis_relu1_reshape = tf.reshape(dis_relu1, [-1,28,28,1])
            z_text = tf.concat([input, image_input, dis_relu1_reshape], 3)
            print z_text.shape
            
            dis_conv1 = conv2d(z_text, 7, 1, 32, 'conv1')
            dis_lrelu1 = leaky_relu(dis_conv1)
            dis_maxpool1 = max_pool(dis_lrelu1,3,2 )
            print dis_maxpool1.shape
            
            dis_conv2 = conv2d(dis_maxpool1, 5, 1, 64, 'conv2')
            dis_batchnorm2 = batch_norm(dis_conv2, self.is_train)
            dis_lrelu2 = leaky_relu(dis_batchnorm2)
            dis_maxpool2 = max_pool(dis_lrelu2,3,2) 
            print dis_maxpool2.shape
            
            dis_conv3 = conv2d(dis_maxpool2, 5, 1, 32, 'conv3')
            dis_batchnorm3 = batch_norm(dis_conv3, self.is_train)
            dis_lrelu3 = leaky_relu(dis_batchnorm3)
            dis_mazpool3 = max_pool(dis_lrelu3,3,2) 
            print dis_mazpool3.shape
            
            dis_reshape3 = tf.reshape(dis_mazpool3, [-1, 4 * 4 * 32])
            dis_fc4 = fc(dis_reshape3, 256, 'fc4')
            dis_lrelu3 = leaky_relu(dis_fc4)
            dis_fc5 = fc(dis_lrelu3, 10, 'fc5')
            dis_lrelu4 = leaky_relu(dis_fc5)
            dis_fc6 = fc(dis_lrelu4, 1, 'fc6')
            # dis_sigmoid= tf.sigmoid(dis_fc5)
            print dis_fc6.shape
            return dis_fc6

    def _generator(self, noise,text_embedding, image_input):
        with tf.variable_scope('gen', reuse = self._gen_called):
            self._gen_called = True
            gen_fc1 = fc(text_embedding, 256, 'fc1')
            gen_relu1 = leaky_relu(gen_fc1)
            z_text = tf.concat([noise, gen_relu1], 1)
            
            gen_fc2 = fc(z_text, 784*2, 'fc2')
            gen_relu2 = leaky_relu(gen_fc2)
            
            gen_reshape1 = tf.reshape(gen_relu2, [-1, 28, 28, 2])
            print gen_reshape1.shape
            image_reshape = tf.concat([image_input, gen_reshape1],3)
            print image_reshape.shape
            
            gen_batchnorm1 = batch_norm(image_reshape, self.is_train)
            gen_lrelu1 = leaky_relu(gen_batchnorm1)
            print gen_lrelu1.shape
            gen_conv2 = conv2d(gen_lrelu1, 4, 1, 64, 'conv2')
            gen_batchnorm2 = batch_norm(gen_conv2, self.is_train)
            gen_lrelu2 = leaky_relu(gen_batchnorm2)
            print(gen_lrelu2.shape)
            gen_conv3 = conv2d(gen_lrelu2, 4, 1, 32, 'conv3')
            gen_batchnorm3 = batch_norm(gen_conv3, self.is_train)
            gen_lrelu3 = leaky_relu(gen_batchnorm3)
            gen_conv4 = conv2d(gen_lrelu3, 4, 1, 1, 'conv4')
            
            gen_sigmoid4 = tf.sigmoid(gen_conv4)
            print(gen_sigmoid4.shape)
            return gen_sigmoid4

    def _loss(self, labels, logits):
        loss = tf.nn.sigmoid_cross_entropy_with_logits(labels = labels, logits = logits)
        return tf.reduce_mean(loss)

    def _reconstruction_loss(self, generated, target):
        loss = tf.nn.l2_loss(generated - target)
        return tf.reduce_mean(loss)
    
    # Define operations
    def _init_ops(self):
        
        ################################################################################
        # Prob 2-1: complete the definition of these operations                        #
        ################################################################################
        
        self.fake_samples_op = self._generator(self.noise, self.real_sentences,self.real_images)
        self.dis_loss_op = self._loss(self.real_labels,self._discriminator(self.real_output_images, self.real_sentences, self.real_images)) + self._loss(self.fake_labels,self._discriminator(self.fake_samples_op, self.real_sentences, self.real_images))
        
        self.gen_loss_op = self._loss(self.real_labels, self._discriminator(self.fake_samples_op, self.real_sentences, self.real_images))
        

        
        dis_optimizer = tf.train.RMSPropOptimizer(self.learning_rate)
        first_train_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,
                                     "dis")
        self.dis_train_op = dis_optimizer.minimize(self.dis_loss_op,var_list = first_train_vars)
        
        gen_optimizer = tf.train.RMSPropOptimizer(self.learning_rate)
        second_train_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,
                                     "gen")
        self.gen_train_op = gen_optimizer.minimize(self.gen_loss_op, var_list = second_train_vars)

    # Training function
    def train(self, sess,train_images,train_sentences,train_labels ):
        sess.run(tf.global_variables_initializer())

        num_train = train_images.shape[0]
        step = 0
        
        # smooth the loss curve so that it does not fluctuate too much
        smooth_factor = 0.95
        plot_dis_s = 0
        plot_gen_s = 0
        plot_ws = 0
        
        dis_losses = []
        gen_losses = []
        for epoch in range(self.num_epoch):
            for i in range(num_train // (self.batch_size)):
                step += 1

                image_batch = train_images[i * self.batch_size : (i + 1) * self.batch_size]
                output_batch = train_output[i * self.batch_size : (i + 1) * self.batch_size]
                sentence_batch = train_sentences[i * self.batch_size : (i + 1) * self.batch_size]
                noise = np.random.normal(0, 1, [self.batch_size, 256])
                real_labels = np.ones([self.batch_size,1])
                
                dis_feed_dict = {self.real_images:image_batch, self.real_output_images:output_batch, self.real_sentences:sentence_batch ,self.real_labels:real_labels, self.fake_labels:np.zeros([self.batch_size,1]), self.noise:noise, self.is_train:True}
                _, dis_loss = sess.run([self.dis_train_op, self.dis_loss_op], feed_dict = dis_feed_dict)
        
                
                gen_feed_dict = {self.noise:noise,self.real_images:image_batch, self.real_sentences:sentence_batch, self.real_labels:real_labels,self.is_train:True}
                _, gen_loss = sess.run([self.gen_train_op, self.gen_loss_op], feed_dict = gen_feed_dict)

                plot_dis_s = plot_dis_s * smooth_factor + dis_loss * (1 - smooth_factor)
                plot_gen_s = plot_gen_s * smooth_factor + gen_loss * (1 - smooth_factor)
                plot_ws = plot_ws * smooth_factor + (1 - smooth_factor)
                dis_losses.append(plot_dis_s / plot_ws)
                gen_losses.append(plot_gen_s / plot_ws)

                if step % self.log_step == 0:
                    print('Iteration {0}: dis loss = {1:.4f}, gen loss = {2:.4f}'.format(step, dis_loss, gen_loss))

            #fig = plt.figure(figsize = (8, 8))   
            #ax1 = plt.subplot(111)
            #generated_image = self.generate(self.tracked_noise)
            #print(generated_image.shape)
            #image = viz_grid(generated_image, 1)
            #print(image.shape)
            #image = image.reshape(30,30)
            #list = []
            #for i in range(3):
                #for j in range(image.shape[0]):
                    #list.append(image[j])
            #image = np.array(list)
            #image = image.reshape(30,30,3)
            
            fig = plt.figure(figsize = (8, 8))   
            ax1 = plt.subplot(111)
            gen = self.generate(self.tracked_noise)
            print (gen.shape)
            images = viz_grid(gen, 1)
            images = images.reshape(233,233)
            ax1.imshow(images,cmap='gray')
            plt.show()

            plt.plot(dis_losses)
            plt.title('discriminator loss')
            plt.xlabel('iterations')
            plt.ylabel('loss')
            plt.show()

            plt.plot(gen_losses)
            plt.title('generator loss')
            plt.xlabel('iterations')
            plt.ylabel('loss')
            plt.show()
            self.batch_size = self.batch_size - 2


    # Generates a single sample from input code
    def generate_one_sample(self, code, i):
        
        ################################################################################
        # Prob 2-1: complete the feed dictionary                                       #
        ################################################################################
        image_batch = train_images[ i : i+1]
        sentence_batch = train_sentences[i : i+1]
        gen_vis_feed_dict = {self.noise:code,self.real_images:image_batch, self.real_sentences:sentence_batch, self.is_train:True}
        
        ################################################################################
        #                               END OF YOUR CODE                               #
        ################################################################################
        
        generated = sess.run(self.fake_samples_op, feed_dict = gen_vis_feed_dict)
        return generated

    # Generates samples from input batch of codes
    def generate(self, codes):
        generated = np.zeros((codes.shape[0], 28, 28, 1))
        for i in range(codes.shape[0]):
            generated[i:i+1] = self.generate_one_sample(codes[i:i+1],i)
        return generated



    # Perform activation maximization on a batch of different initial codes
    def actmax(self, initial_codes):
        actmax_results = np.zeros((initial_codes.shape[0], 32, 32, 3))
        for i in range(initial_codes.shape[0]):
            actmax_results[i:i+1] = self.actmax_one_sample(initial_codes[i:i+1])
        return actmax_results.clip(0, 1)
    
tf.reset_default_graph()

with tf.Session() as sess:
    dcgan = DCGAN()
    sess.run(tf.global_variables_initializer())
    train_images = np.array(train_images)
    train_sentences = np.array(train_sentences)
    train_labels = np.array(train_labels)
    train_images = np.array(train_images)
    dcgan.train(sess, train_images,train_sentences,train_labels)
    dis_var_list = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, 'dis')
    gen_var_list = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, 'gen')
    saver = tf.train.Saver(dis_var_list + gen_var_list)
    saver.save(sess, 'model/dcgan')
# Out:
# (?, 28, 28, 2)
# (?, 28, 28, 3)
# (?, 28, 28, 3)
# (?, 28, 28, 64)
# (?, 28, 28, 1)
# (?, 28, 28, 3)
# (?, 14, 14, 32)
# (?, 7, 7, 64)
# (?, 4, 4, 32)
# (?, 1)
# (?, 28, 28, 3)
# (?, 14, 14, 32)
# (?, 7, 7, 64)
# (?, 4, 4, 32)
# (?, 1)
# (?, 28, 28, 3)
# (?, 14, 14, 32)
# (?, 7, 7, 64)
# (?, 4, 4, 32)
# (?, 1)
# Iteration 50: dis loss = 1.3870, gen loss = 0.6913
# Iteration 100: dis loss = 1.3837, gen loss = 0.6949
# Iteration 150: dis loss = 1.2308, gen loss = 0.7710
# Iteration 200: dis loss = 0.5181, gen loss = 1.3800
# Iteration 250: dis loss = 0.1487, gen loss = 2.6035
# Iteration 300: dis loss = 0.2837, gen loss = 2.2409
# Iteration 350: dis loss = 0.3474, gen loss = 1.9172
# Iteration 400: dis loss = 0.8138, gen loss = 0.9289
# Iteration 450: dis loss = 0.9680, gen loss = 0.9932
# Iteration 500: dis loss = 0.8503, gen loss = 2.9542
# Iteration 550: dis loss = 0.5691, gen loss = 1.5413
# Iteration 600: dis loss = 1.0459, gen loss = 2.7973
# Iteration 650: dis loss = 0.3488, gen loss = 3.0100
# Iteration 700: dis loss = 0.2882, gen loss = 2.3602
# Iteration 750: dis loss = 0.3516, gen loss = 2.3620
# Iteration 800: dis loss = 0.7153, gen loss = 1.3341
# Iteration 850: dis loss = 0.4450, gen loss = 2.4504
# Iteration 900: dis loss = 0.4278, gen loss = 3.1405
# Iteration 950: dis loss = 0.2444, gen loss = 3.0796
# Iteration 1000: dis loss = 0.2142, gen loss = 2.7987
# Iteration 1050: dis loss = 0.2781, gen loss = 4.4034
# Iteration 1100: dis loss = 0.0276, gen loss = 5.0025
# Iteration 1150: dis loss = 0.0526, gen loss = 5.0409
# Iteration 1200: dis loss = 0.0600, gen loss = 4.3847
# Iteration 1250: dis loss = 0.1960, gen loss = 4.4979
# Iteration 1300: dis loss = 0.1958, gen loss = 5.9748
# Iteration 1350: dis loss = 0.2095, gen loss = 3.1619
# Iteration 1400: dis loss = 0.3997, gen loss = 0.5270
# Iteration 1450: dis loss = 0.5132, gen loss = 2.7512
# Iteration 1500: dis loss = 0.0170, gen loss = 5.6440
# Iteration 1550: dis loss = 0.0166, gen loss = 6.1370
# Iteration 1600: dis loss = 0.0240, gen loss = 5.8705
# Iteration 1650: dis loss = 0.0736, gen loss = 2.8995
# Iteration 1700: dis loss = 0.0246, gen loss = 7.1523
# Iteration 1750: dis loss = 0.0151, gen loss = 5.5973
# Iteration 1800: dis loss = 0.0081, gen loss = 6.4466
# Iteration 1850: dis loss = 0.0402, gen loss = 5.0630
# Iteration 1900: dis loss = 0.0223, gen loss = 6.5636
# Iteration 1950: dis loss = 0.0223, gen loss = 5.3126
# Iteration 2000: dis loss = 1.0917, gen loss = 2.4027
# Iteration 2050: dis loss = 0.0454, gen loss = 4.3407
# Iteration 2100: dis loss = 0.0357, gen loss = 5.8214
# Iteration 2150: dis loss = 0.0094, gen loss = 6.2572
# Iteration 2200: dis loss = 0.0937, gen loss = 3.8602
# Iteration 2250: dis loss = 0.0059, gen loss = 6.7099
# Iteration 2300: dis loss = 0.0602, gen loss = 4.1917
# Iteration 2350: dis loss = 0.0464, gen loss = 4.8618
# Iteration 2400: dis loss = 0.0511, gen loss = 4.9005
# Iteration 2450: dis loss = 0.0182, gen loss = 5.9493
# Iteration 2500: dis loss = 0.0189, gen loss = 5.8588
# Iteration 2550: dis loss = 0.0264, gen loss = 7.0188
# Iteration 2600: dis loss = 0.0224, gen loss = 5.7972
# Iteration 2650: dis loss = 0.0175, gen loss = 6.6370
# Iteration 2700: dis loss = 0.0661, gen loss = 5.1962
# Iteration 2750: dis loss = 0.0487, gen loss = 5.2519
# Iteration 2800: dis loss = 0.0077, gen loss = 7.2643
# Iteration 2850: dis loss = 0.0094, gen loss = 6.2841
# Iteration 2900: dis loss = 0.0135, gen loss = 6.2465
# Iteration 2950: dis loss = 0.0027, gen loss = 10.1335
# Iteration 3000: dis loss = 0.1487, gen loss = 7.4986
# Iteration 3050: dis loss = 0.0365, gen loss = 5.5585
# Iteration 3100: dis loss = 0.0068, gen loss = 6.7049
# Iteration 3150: dis loss = 0.0089, gen loss = 6.7990
# Iteration 3200: dis loss = 0.0364, gen loss = 5.3457
# Iteration 3250: dis loss = 0.0159, gen loss = 6.2558
# Iteration 3300: dis loss = 0.0114, gen loss = 6.1831
# Iteration 3350: dis loss = 0.0014, gen loss = 8.5911
# Iteration 3400: dis loss = 0.0108, gen loss = 6.0932
# Iteration 3450: dis loss = 0.0103, gen loss = 6.0248
# Iteration 3500: dis loss = 0.1438, gen loss = 3.6678
# Iteration 3550: dis loss = 0.2722, gen loss = 2.3869
# Iteration 3600: dis loss = 0.0158, gen loss = 7.0028
# Iteration 3650: dis loss = 0.0227, gen loss = 5.4793
# Iteration 3700: dis loss = 0.0058, gen loss = 9.5677
# Iteration 3750: dis loss = 0.0210, gen loss = 7.0041
# Iteration 3800: dis loss = 0.0158, gen loss = 6.4357
# Iteration 3850: dis loss = 0.0324, gen loss = 5.3411
# Iteration 3900: dis loss = 0.0253, gen loss = 6.4055
# Iteration 3950: dis loss = 0.0443, gen loss = 4.6485
# Iteration 4000: dis loss = 0.0088, gen loss = 7.0977
# Iteration 4050: dis loss = 0.0089, gen loss = 7.8321
# Iteration 4100: dis loss = 0.0979, gen loss = 8.5321
# Iteration 4150: dis loss = 0.0283, gen loss = 4.8771
# Iteration 4200: dis loss = 0.0080, gen loss = 7.6305
# Iteration 4250: dis loss = 0.0088, gen loss = 6.5487
# Iteration 4300: dis loss = 0.2615, gen loss = 4.4476
# Iteration 4350: dis loss = 0.0785, gen loss = 9.5579
# Iteration 4400: dis loss = 0.0558, gen loss = 5.8794
# Iteration 4450: dis loss = 0.0635, gen loss = 6.3570
# Iteration 4500: dis loss = 0.0144, gen loss = 7.0282
# Iteration 4550: dis loss = 0.1209, gen loss = 4.7801
# Iteration 4600: dis loss = 0.0136, gen loss = 6.2926
# Iteration 4650: dis loss = 0.0100, gen loss = 6.4379
# Iteration 4700: dis loss = 0.0028, gen loss = 8.1858
# Iteration 4750: dis loss = 0.0248, gen loss = 8.6985
# Iteration 4800: dis loss = 0.0013, gen loss = 7.4408
# Iteration 4850: dis loss = 0.1629, gen loss = 7.7781
# Iteration 4900: dis loss = 0.3831, gen loss = 3.4211
# Iteration 4950: dis loss = 0.1011, gen loss = 9.2578
# Iteration 5000: dis loss = 0.0033, gen loss = 7.5307
# Iteration 5050: dis loss = 0.0035, gen loss = 7.4697
# Iteration 5100: dis loss = 0.0740, gen loss = 7.3253
# Iteration 5150: dis loss = 0.1024, gen loss = 4.3079
# Iteration 5200: dis loss = 0.0236, gen loss = 6.7578
# Iteration 5250: dis loss = 0.0024, gen loss = 9.2667
# Iteration 5300: dis loss = 0.0426, gen loss = 7.3161
# Iteration 5350: dis loss = 0.0197, gen loss = 6.3069
# Iteration 5400: dis loss = 4.2919, gen loss = 13.2309
# Iteration 5450: dis loss = 0.0005, gen loss = 8.6736
# Iteration 5500: dis loss = 0.0215, gen loss = 6.1016
# Iteration 5550: dis loss = 0.0084, gen loss = 11.9952
# Iteration 5600: dis loss = 0.0006, gen loss = 9.0863
# Iteration 5650: dis loss = 0.0003, gen loss = 9.4115
# Iteration 5700: dis loss = 2.6861, gen loss = 13.6400
# Iteration 5750: dis loss = 0.0083, gen loss = 7.5103
# Iteration 5800: dis loss = 0.0218, gen loss = 6.9274
# Iteration 5850: dis loss = 0.0023, gen loss = 8.1375
# Iteration 5900: dis loss = 0.1248, gen loss = 3.4608
# Iteration 5950: dis loss = 0.0052, gen loss = 8.4911
# Iteration 6000: dis loss = 0.0104, gen loss = 6.4662
# Iteration 6050: dis loss = 0.0169, gen loss = 7.0823
# Iteration 6100: dis loss = 0.0094, gen loss = 6.4770
# Iteration 6150: dis loss = 0.0095, gen loss = 10.4842
# Iteration 6200: dis loss = 0.0275, gen loss = 6.6812
# Iteration 6250: dis loss = 0.0038, gen loss = 7.4486
# Iteration 6300: dis loss = 0.1106, gen loss = 1.5822
# Iteration 6350: dis loss = 0.0012, gen loss = 11.4171
# Iteration 6400: dis loss = 0.0075, gen loss = 9.7203
# Iteration 6450: dis loss = 0.0024, gen loss = 7.7951
# Iteration 6500: dis loss = 0.0015, gen loss = 7.9177
# Iteration 6550: dis loss = 0.0023, gen loss = 7.5431
# Iteration 6600: dis loss = 0.0010, gen loss = 9.0389
# Iteration 6650: dis loss = 0.0671, gen loss = 7.2344
# Iteration 6700: dis loss = 0.0009, gen loss = 8.0599
# Iteration 6750: dis loss = 0.0012, gen loss = 8.8718
# Iteration 6800: dis loss = 0.0027, gen loss = 7.9678
# Iteration 6850: dis loss = 0.2255, gen loss = 7.0438
# Iteration 6900: dis loss = 0.0088, gen loss = 6.8314
# Iteration 6950: dis loss = 0.2251, gen loss = 10.8896
# Iteration 7000: dis loss = 0.0278, gen loss = 8.7380
# Iteration 7050: dis loss = 0.0011, gen loss = 10.5529
# Iteration 7100: dis loss = 0.0034, gen loss = 8.0854
# Iteration 7150: dis loss = 0.0035, gen loss = 10.9534
# Iteration 7200: dis loss = 0.0080, gen loss = 7.1924
# Iteration 7250: dis loss = 0.0013, gen loss = 8.1049
# Iteration 7300: dis loss = 0.0011, gen loss = 9.8120
# Iteration 7350: dis loss = 0.0031, gen loss = 9.9183
# Iteration 7400: dis loss = 0.0054, gen loss = 8.7552
# Iteration 7450: dis loss = 0.0126, gen loss = 7.6168
# Iteration 7500: dis loss = 0.0006, gen loss = 9.4178
# Iteration 7550: dis loss = 0.0004, gen loss = 9.4196
# Iteration 7600: dis loss = 0.0046, gen loss = 6.8440
# Iteration 7650: dis loss = 0.0047, gen loss = 7.1580
# Iteration 7700: dis loss = 0.0340, gen loss = 11.4773
# Iteration 7750: dis loss = 2.4103, gen loss = 14.6682
# Iteration 7800: dis loss = 0.0252, gen loss = 9.2650
# Iteration 7850: dis loss = 0.0057, gen loss = 6.8893
# Iteration 7900: dis loss = 0.0017, gen loss = 8.1639
# Iteration 7950: dis loss = 0.0017, gen loss = 10.8649
# Iteration 8000: dis loss = 0.8923, gen loss = 13.9041
# Iteration 8050: dis loss = 0.0104, gen loss = 7.8697
# Iteration 8100: dis loss = 0.0045, gen loss = 7.0070
# Iteration 8150: dis loss = 0.0616, gen loss = 10.4714
# Iteration 8200: dis loss = 0.0037, gen loss = 7.6094
# Iteration 8250: dis loss = 5.4809, gen loss = 11.4236
# Iteration 8300: dis loss = 0.0001, gen loss = 11.9771
# Iteration 8350: dis loss = 0.0006, gen loss = 9.1325
# Iteration 8400: dis loss = 0.0122, gen loss = 6.0658
# Iteration 8450: dis loss = 0.1467, gen loss = 1.8992
# Iteration 8500: dis loss = 0.3088, gen loss = 16.8973
# Iteration 8550: dis loss = 0.0251, gen loss = 8.3989
# Iteration 8600: dis loss = 0.0375, gen loss = 9.2446
# Iteration 8650: dis loss = 0.0029, gen loss = 7.4711
# Iteration 8700: dis loss = 0.0141, gen loss = 8.4826
# Iteration 8750: dis loss = 0.0066, gen loss = 10.2338
# Iteration 8800: dis loss = 0.0019, gen loss = 12.2687
# Iteration 8850: dis loss = 0.0007, gen loss = 9.2753
# Iteration 8900: dis loss = 0.1558, gen loss = 8.5270
# Iteration 8950: dis loss = 0.0188, gen loss = 6.8812
# Iteration 9000: dis loss = 0.0003, gen loss = 9.8107
# Iteration 9050: dis loss = 0.0039, gen loss = 7.8341
# Iteration 9100: dis loss = 0.0078, gen loss = 7.9321
# Iteration 9150: dis loss = 0.0053, gen loss = 8.4468
# Iteration 9200: dis loss = 0.0022, gen loss = 7.1896
# Iteration 9250: dis loss = 0.0172, gen loss = 6.9690
# Iteration 9300: dis loss = 0.0081, gen loss = 7.3626
# Iteration 9350: dis loss = 0.0193, gen loss = 6.4623
# (64, 28, 28, 1)
# Iteration 9400: dis loss = 0.0031, gen loss = 9.0221
# Iteration 9450: dis loss = 0.0056, gen loss = 8.9707
# Iteration 9500: dis loss = 0.0019, gen loss = 8.4100
# Iteration 9550: dis loss = 0.0003, gen loss = 9.4738
# Iteration 9600: dis loss = 6.9146, gen loss = 9.0739
# Iteration 9650: dis loss = 0.0002, gen loss = 11.0024
# Iteration 9700: dis loss = 1.2537, gen loss = 2.0356
# Iteration 9750: dis loss = 0.0064, gen loss = 7.1957
# Iteration 9800: dis loss = 0.0003, gen loss = 9.7104
# Iteration 9850: dis loss = 0.0024, gen loss = 7.6412
# Iteration 9900: dis loss = 0.0032, gen loss = 9.1299
# Iteration 9950: dis loss = 0.0003, gen loss = 13.5144
# Iteration 10000: dis loss = 0.0001, gen loss = 10.9964
# Iteration 10050: dis loss = 0.0409, gen loss = 7.4368
# Iteration 10100: dis loss = 0.0005, gen loss = 8.8646
# Iteration 10150: dis loss = 0.0006, gen loss = 8.7091
# Iteration 10200: dis loss = 0.0005, gen loss = 9.4792
# Iteration 10250: dis loss = 0.0030, gen loss = 7.4041
# Iteration 10300: dis loss = 0.0045, gen loss = 8.0277
# Iteration 10350: dis loss = 0.0016, gen loss = 7.8558
# Iteration 10400: dis loss = 0.1192, gen loss = 12.1729
# Iteration 10450: dis loss = 0.0019, gen loss = 8.2379
# Iteration 10500: dis loss = 0.0016, gen loss = 8.2570
# Iteration 10550: dis loss = 0.0006, gen loss = 10.5481
# Iteration 10600: dis loss = 0.0261, gen loss = 11.5489
# Iteration 10650: dis loss = 0.0004, gen loss = 9.1084
# Iteration 10700: dis loss = 0.0014, gen loss = 14.5001
# Iteration 10750: dis loss = 0.0001, gen loss = 10.4984
# Iteration 10800: dis loss = 0.0001, gen loss = 11.5258
# Iteration 10850: dis loss = 0.1627, gen loss = 0.3492
# Iteration 10900: dis loss = 0.0234, gen loss = 12.1514
# Iteration 10950: dis loss = 0.3322, gen loss = 9.7307
# Iteration 11000: dis loss = 0.0001, gen loss = 11.6706
# Iteration 11050: dis loss = 0.0001, gen loss = 10.8500
# Iteration 11100: dis loss = 0.0001, gen loss = 12.7912
# Iteration 11150: dis loss = 0.0018, gen loss = 7.7079
# Iteration 11200: dis loss = 0.0005, gen loss = 8.6836
# Iteration 11250: dis loss = 0.0033, gen loss = 7.4441
# Iteration 11300: dis loss = 0.0005, gen loss = 8.9381
# Iteration 11350: dis loss = 0.0001, gen loss = 12.8614
# Iteration 11400: dis loss = 0.0209, gen loss = 9.1144
# Iteration 11450: dis loss = 0.0000, gen loss = 12.7510
# Iteration 11500: dis loss = 0.0344, gen loss = 11.3722
# Iteration 11550: dis loss = 0.0015, gen loss = 9.3084
# Iteration 11600: dis loss = 0.0003, gen loss = 11.4432
# Iteration 11650: dis loss = 0.0029, gen loss = 7.9200
# Iteration 11700: dis loss = 0.0006, gen loss = 9.4644
# Iteration 11750: dis loss = 0.0002, gen loss = 11.7114
# Iteration 11800: dis loss = 0.0026, gen loss = 11.6250
# Iteration 11850: dis loss = 0.0007, gen loss = 14.2908
# Iteration 11900: dis loss = 0.0001, gen loss = 10.8018
# Iteration 11950: dis loss = 0.0001, gen loss = 12.1317
# Iteration 12000: dis loss = 0.3279, gen loss = 11.6927
# Iteration 12050: dis loss = 0.0001, gen loss = 11.6199
# Iteration 12100: dis loss = 0.0183, gen loss = 13.1840
# Iteration 12150: dis loss = 0.0007, gen loss = 11.0937
# Iteration 12200: dis loss = 0.0003, gen loss = 9.2556
# Iteration 12250: dis loss = 0.0000, gen loss = 11.5150
# Iteration 12300: dis loss = 0.0005, gen loss = 10.2523
# Iteration 12350: dis loss = 0.0013, gen loss = 11.2667
# Iteration 12400: dis loss = 0.0001, gen loss = 12.2537
# Iteration 12450: dis loss = 0.0001, gen loss = 13.0913
# Iteration 12500: dis loss = 0.0005, gen loss = 11.7144
# Iteration 12550: dis loss = 0.0003, gen loss = 9.7129
# Iteration 12600: dis loss = 0.0009, gen loss = 8.5510
# Iteration 12650: dis loss = 0.0001, gen loss = 12.3081
# Iteration 12700: dis loss = 0.0317, gen loss = 6.0581
# Iteration 12750: dis loss = 0.0000, gen loss = 13.8366
# Iteration 12800: dis loss = 0.0000, gen loss = 12.2514
# Iteration 12850: dis loss = 0.0002, gen loss = 11.7175
# Iteration 12900: dis loss = 0.0001, gen loss = 10.6363
# Iteration 12950: dis loss = 0.0007, gen loss = 8.5382
# Iteration 13000: dis loss = 0.0001, gen loss = 11.3595
# Iteration 13050: dis loss = 0.0032, gen loss = 13.2985
# Iteration 13100: dis loss = 0.0059, gen loss = 11.0231
# Iteration 13150: dis loss = 0.0003, gen loss = 10.0869
# Iteration 13200: dis loss = 0.0066, gen loss = 9.4936
# Iteration 13250: dis loss = 0.0002, gen loss = 10.1390
# Iteration 13300: dis loss = 0.0116, gen loss = 16.6265
# Iteration 13350: dis loss = 0.0002, gen loss = 10.3770
# Iteration 13400: dis loss = 0.0116, gen loss = 13.4717
# Iteration 13450: dis loss = 0.0196, gen loss = 12.0024
# Iteration 13500: dis loss = 0.0006, gen loss = 8.3432
# Iteration 13550: dis loss = 0.0053, gen loss = 8.2539
# Iteration 13600: dis loss = 0.0000, gen loss = 14.2988
# Iteration 13650: dis loss = 0.0004, gen loss = 11.4964
# Iteration 13700: dis loss = 0.0000, gen loss = 12.3417
# Iteration 13750: dis loss = 0.0589, gen loss = 11.7526
# Iteration 13800: dis loss = 0.0023, gen loss = 9.4582
# Iteration 13850: dis loss = 0.0019, gen loss = 8.5805
# Iteration 13900: dis loss = 0.0254, gen loss = 7.8697
# Iteration 13950: dis loss = 0.0074, gen loss = 11.5169
# Iteration 14000: dis loss = 0.0009, gen loss = 15.8914
# Iteration 14050: dis loss = 0.0000, gen loss = 13.9850
# Iteration 14100: dis loss = 0.0005, gen loss = 9.8026
# Iteration 14150: dis loss = 0.0003, gen loss = 9.3100
# Iteration 14200: dis loss = 0.0000, gen loss = 12.9363
# Iteration 14250: dis loss = 0.0000, gen loss = 11.4707
# Iteration 14300: dis loss = 0.0016, gen loss = 9.0378
# Iteration 14350: dis loss = 0.0273, gen loss = 11.2576
# Iteration 14400: dis loss = 0.8648, gen loss = 10.4091
# Iteration 14450: dis loss = 0.0299, gen loss = 15.3518
# Iteration 14500: dis loss = 0.0000, gen loss = 13.8704
# Iteration 14550: dis loss = 0.0237, gen loss = 9.5082
# Iteration 14600: dis loss = 0.3122, gen loss = 13.7008
# Iteration 14650: dis loss = 0.0001, gen loss = 13.1117
# Iteration 14700: dis loss = 0.0000, gen loss = 11.4633
# Iteration 14750: dis loss = 0.0003, gen loss = 12.7720
# Iteration 14800: dis loss = 0.0001, gen loss = 10.5370
# Iteration 14850: dis loss = 0.0177, gen loss = 11.9728
# Iteration 14900: dis loss = 0.0000, gen loss = 12.0692
# Iteration 14950: dis loss = 0.0149, gen loss = 14.1728
# Iteration 15000: dis loss = 0.0001, gen loss = 12.1528
# Iteration 15050: dis loss = 0.0006, gen loss = 13.0003
# Iteration 15100: dis loss = 0.0000, gen loss = 13.0345
# Iteration 15150: dis loss = 0.0046, gen loss = 9.2316
# Iteration 15200: dis loss = 0.0002, gen loss = 11.1412
# Iteration 15250: dis loss = 0.0002, gen loss = 12.5746
# Iteration 15300: dis loss = 0.0001, gen loss = 15.0140
# Iteration 15350: dis loss = 0.0000, gen loss = 12.8313
# Iteration 15400: dis loss = 0.0000, gen loss = 13.6223
# Iteration 15450: dis loss = 0.0143, gen loss = 11.8006
# Iteration 15500: dis loss = 0.2649, gen loss = 14.3380
# Iteration 15550: dis loss = 0.0003, gen loss = 9.3318
# Iteration 15600: dis loss = 0.0000, gen loss = 13.6877
# Iteration 15650: dis loss = 0.0100, gen loss = 7.1682
# Iteration 15700: dis loss = 0.0000, gen loss = 13.8489
# Iteration 15750: dis loss = 0.0001, gen loss = 12.2822
# Iteration 15800: dis loss = 0.0031, gen loss = 9.8453
# Iteration 15850: dis loss = 0.0011, gen loss = 9.4715
# Iteration 15900: dis loss = 0.0006, gen loss = 17.0366
# Iteration 15950: dis loss = 0.0362, gen loss = 9.0160
# Iteration 16000: dis loss = 0.0002, gen loss = 10.9257
# Iteration 16050: dis loss = 0.0531, gen loss = 9.9290
# Iteration 16100: dis loss = 0.0001, gen loss = 10.7650
# Iteration 16150: dis loss = 0.0003, gen loss = 9.5110
# Iteration 16200: dis loss = 0.0005, gen loss = 9.9317
# Iteration 16250: dis loss = 0.0636, gen loss = 2.0788
# Iteration 16300: dis loss = 0.0006, gen loss = 9.6084
# Iteration 16350: dis loss = 0.0003, gen loss = 10.1735
# Iteration 16400: dis loss = 0.0000, gen loss = 17.2442
# Iteration 16450: dis loss = 0.0000, gen loss = 17.7134
# Iteration 16500: dis loss = 0.0002, gen loss = 11.3720
# Iteration 16550: dis loss = 0.0002, gen loss = 12.6792
# Iteration 16600: dis loss = 0.0002, gen loss = 10.6930
# Iteration 16650: dis loss = 0.0192, gen loss = 9.1991
# Iteration 16700: dis loss = 0.0000, gen loss = 11.9190
# Iteration 16750: dis loss = 0.0000, gen loss = 11.2416
# Iteration 16800: dis loss = 0.0001, gen loss = 12.0713
# Iteration 16850: dis loss = 0.0000, gen loss = 13.7162
# Iteration 16900: dis loss = 0.0000, gen loss = 14.9258
# Iteration 16950: dis loss = 0.0004, gen loss = 17.8360
# Iteration 17000: dis loss = 0.0000, gen loss = 12.3830
# Iteration 17050: dis loss = 0.0003, gen loss = 12.2141
# Iteration 17100: dis loss = 0.0001, gen loss = 10.6683
# Iteration 17150: dis loss = 0.0017, gen loss = 13.9465
# Iteration 17200: dis loss = 0.0000, gen loss = 11.5381
# Iteration 17250: dis loss = 0.0002, gen loss = 15.1553
# Iteration 17300: dis loss = 0.0000, gen loss = 12.6846
# Iteration 17350: dis loss = 0.0002, gen loss = 10.7695
# Iteration 17400: dis loss = 0.0001, gen loss = 10.6144
# Iteration 17450: dis loss = 0.0002, gen loss = 10.7274
# Iteration 17500: dis loss = 0.0000, gen loss = 12.1600
# Iteration 17550: dis loss = 0.0098, gen loss = 8.2024
# Iteration 17600: dis loss = 0.0002, gen loss = 14.5335
# Iteration 17650: dis loss = 0.0031, gen loss = 7.4232
# Iteration 17700: dis loss = 0.0006, gen loss = 13.9695
# Iteration 17750: dis loss = 0.0001, gen loss = 14.6819
# Iteration 17800: dis loss = 0.0000, gen loss = 12.5972
# Iteration 17850: dis loss = 0.0001, gen loss = 15.5001
# Iteration 17900: dis loss = 0.0087, gen loss = 16.6252
# Iteration 17950: dis loss = 0.0001, gen loss = 12.0964
# Iteration 18000: dis loss = 0.0000, gen loss = 14.9173
# Iteration 18050: dis loss = 0.0000, gen loss = 17.2973
# Iteration 18100: dis loss = 0.1950, gen loss = 19.6124
# Iteration 18150: dis loss = 0.0000, gen loss = 12.0527
# Iteration 18200: dis loss = 0.0813, gen loss = 9.6606
# Iteration 18250: dis loss = 0.0000, gen loss = 11.8794
# Iteration 18300: dis loss = 0.0079, gen loss = 7.6329
# Iteration 18350: dis loss = 0.0001, gen loss = 11.8140
# Iteration 18400: dis loss = 0.0000, gen loss = 12.2530
# Iteration 18450: dis loss = 0.0002, gen loss = 9.8971
# Iteration 18500: dis loss = 0.0096, gen loss = 11.8275
# Iteration 18550: dis loss = 0.0042, gen loss = 10.9578
# Iteration 18600: dis loss = 0.0003, gen loss = 10.3784
# Iteration 18650: dis loss = 0.0009, gen loss = 16.4546
# Iteration 18700: dis loss = 0.0000, gen loss = 12.2657
# Iteration 18750: dis loss = 0.0006, gen loss = 14.3761
# Iteration 18800: dis loss = 0.0005, gen loss = 14.5890
# Iteration 18850: dis loss = 0.0061, gen loss = 16.4399
# Iteration 18900: dis loss = 0.0600, gen loss = 11.1421
# Iteration 18950: dis loss = 0.0001, gen loss = 11.8441
# Iteration 19000: dis loss = 0.0029, gen loss = 8.2162
# Iteration 19050: dis loss = 0.0000, gen loss = 13.1387
# (64, 28, 28, 1)
# Iteration 19100: dis loss = 0.0000, gen loss = 14.3782
# Iteration 19150: dis loss = 0.0044, gen loss = 13.6973
# Iteration 19200: dis loss = 0.0000, gen loss = 11.8889
# Iteration 19250: dis loss = 0.0320, gen loss = 11.4275
# Iteration 19300: dis loss = 0.0011, gen loss = 9.2553
# Iteration 19350: dis loss = 0.0035, gen loss = 8.4431
# Iteration 19400: dis loss = 0.0001, gen loss = 12.2655
# Iteration 19450: dis loss = 0.0007, gen loss = 10.0984
# Iteration 19500: dis loss = 0.0558, gen loss = 11.6652
# Iteration 19550: dis loss = 0.0000, gen loss = 15.5188
# Iteration 19600: dis loss = 0.0011, gen loss = 14.6733
# Iteration 19650: dis loss = 0.0000, gen loss = 13.1939
# Iteration 19700: dis loss = 0.0000, gen loss = 20.6432
# Iteration 19750: dis loss = 0.0018, gen loss = 9.7398
# Iteration 19800: dis loss = 0.0002, gen loss = 14.8969
# Iteration 19850: dis loss = 0.0000, gen loss = 12.0956
# Iteration 19900: dis loss = 0.0001, gen loss = 12.1443
# Iteration 19950: dis loss = 0.0046, gen loss = 13.5110
# Iteration 20000: dis loss = 0.0003, gen loss = 17.9463
# Iteration 20050: dis loss = 0.0000, gen loss = 15.6277
# Iteration 20100: dis loss = 0.0007, gen loss = 10.7103
# Iteration 20150: dis loss = 0.0004, gen loss = 9.2539
# Iteration 20200: dis loss = 0.0000, gen loss = 14.2390
# Iteration 20250: dis loss = 0.1518, gen loss = 11.7721
# Iteration 20300: dis loss = 0.0000, gen loss = 11.1480
# Iteration 20350: dis loss = 0.0000, gen loss = 15.2194
# Iteration 20400: dis loss = 0.0001, gen loss = 10.3147
# Iteration 20450: dis loss = 0.0000, gen loss = 14.1598
# Iteration 20500: dis loss = 0.0000, gen loss = 14.5872
# Iteration 20550: dis loss = 0.0001, gen loss = 10.8222
# Iteration 20600: dis loss = 0.0033, gen loss = 13.2492
# Iteration 20650: dis loss = 0.0031, gen loss = 12.6545
# Iteration 20700: dis loss = 0.0036, gen loss = 14.5549
# Iteration 20750: dis loss = 0.0001, gen loss = 12.6596
# Iteration 20800: dis loss = 0.0000, gen loss = 11.2938
# Iteration 20850: dis loss = 0.0011, gen loss = 11.1736
# Iteration 20900: dis loss = 0.0000, gen loss = 12.7449
# Iteration 20950: dis loss = 0.0000, gen loss = 11.6162
# Iteration 21000: dis loss = 0.0000, gen loss = 16.5005
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-18-ed7d931437f7> in <module>()
#     319     train_labels = np.array(train_labels)
#     320     train_images = np.array(train_images)
# --> 321     dcgan.train(sess, train_images,train_sentences,train_labels)
#     322     dis_var_list = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, 'dis')
#     323     gen_var_list = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, 'gen')
#
# <ipython-input-18-ed7d931437f7> in train(self, sess, train_images, train_sentences, train_labels)
#     225
#     226                 dis_feed_dict = {self.real_images:image_batch, self.real_output_images:output_batch, self.real_sentences:sentence_batch ,self.real_labels:real_labels, self.fake_labels:np.zeros([self.batch_size,1]), self.noise:noise, self.is_train:True}
# --> 227                 _, dis_loss = sess.run([self.dis_train_op, self.dis_loss_op], feed_dict = dis_feed_dict)
#     228
#     229
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
